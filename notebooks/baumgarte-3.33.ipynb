# %% [markdown]
# # Baumgarte - 3.33

# %%
from sympy import *
init_printing(use_unicode=True)

# %%
x, y, z, v = symbols('x, y, z, v')
M = symbols('M')
coords = [ x, y, z ]
r = sqrt(x ** 2 + y ** 2 + z ** 2)
gamma = 1 / sqrt(1 - v ** 2)

# %%
flat_metric = Matrix([
    [ -(1 - 2 * M / r), 0, 0, 0 ],
    [ 0, (1 + 2 * M / r), 0, 0 ],
    [ 0, 0, (1 + 2 * M / r), 0 ],
    [ 0, 0, 0, (1 + 2 * M / r) ],
])
flat_metric
# Out:
# ⎡       2⋅M
# ⎢───────────────── - 1            0                      0
# ⎢   ______________
# ⎢  ╱  2    2    2
# ⎢╲╱  x  + y  + z
# ⎢
# ⎢                              2⋅M
# ⎢          0            ───────────────── + 1            0
# ⎢                          ______________
# ⎢                         ╱  2    2    2
# ⎢                       ╲╱  x  + y  + z
# ⎢
# ⎢                                                     2⋅M
# ⎢          0                      0            ───────────────── + 1
# ⎢                                                 ______________
# ⎢                                                ╱  2    2    2
# ⎢                                              ╲╱  x  + y  + z
# ⎢
# ⎢                                                                            2
# ⎢          0                      0                      0            ────────
# ⎢                                                                        _____
# ⎢                                                                       ╱  2
# ⎣                                                                     ╲╱  x  +
#
#              ⎤
#   0          ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
#   0          ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
#   0          ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
# ⋅M           ⎥
# ───────── + 1⎥
# _________    ⎥
#   2    2     ⎥
#  y  + z      ⎦

# %%
boost = Matrix([
    [ gamma, 0, 0, -gamma * v ],
    [ 0, 1, 0, 0 ],
    [ 0, 0, 1, 0],
    [ -gamma * v , 0, 0, gamma ]
])
boost
# Out:
# ⎡     1                 -v     ⎤
# ⎢───────────  0  0  ───────────⎥
# ⎢   ________           ________⎥
# ⎢  ╱      2           ╱      2 ⎥
# ⎢╲╱  1 - v          ╲╱  1 - v  ⎥
# ⎢                              ⎥
# ⎢     0       1  0       0     ⎥
# ⎢                              ⎥
# ⎢     0       0  1       0     ⎥
# ⎢                              ⎥
# ⎢    -v                  1     ⎥
# ⎢───────────  0  0  ───────────⎥
# ⎢   ________           ________⎥
# ⎢  ╱      2           ╱      2 ⎥
# ⎣╲╱  1 - v          ╲╱  1 - v  ⎦

# %%
boosted_metric = (boost * flat_metric * boost.T).applyfunc(simplify)
boosted_metric
# Out:
# ⎡          ⎛         ______________⎞      ______________
# ⎢        2 ⎜        ╱  2    2    2 ⎟     ╱  2    2    2
# ⎢-2⋅M - v ⋅⎝2⋅M + ╲╱  x  + y  + z  ⎠ + ╲╱  x  + y  + z
# ⎢───────────────────────────────────────────────────────            0
# ⎢                           ______________
# ⎢               ⎛ 2    ⎞   ╱  2    2    2
# ⎢               ⎝v  - 1⎠⋅╲╱  x  + y  + z
# ⎢
# ⎢                                                                2⋅M
# ⎢                           0                             ───────────────── +
# ⎢                                                            ______________
# ⎢                                                           ╱  2    2    2
# ⎢                                                         ╲╱  x  + y  + z
# ⎢
# ⎢
# ⎢                           0                                       0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                        4⋅M⋅v
# ⎢              ──────────────────────────                           0
# ⎢                          ______________
# ⎢              ⎛ 2    ⎞   ╱  2    2    2
# ⎣              ⎝v  - 1⎠⋅╲╱  x  + y  + z
#
#
#
#                                                    4⋅M⋅v
#              0                           ──────────────────────────
#                                                      ______________
#                                          ⎛ 2    ⎞   ╱  2    2    2
#                                          ⎝v  - 1⎠⋅╲╱  x  + y  + z
#
#
# 1            0                                       0
#
#
#
#
#           2⋅M
#    ───────────────── + 1                             0
#       ______________
#      ╱  2    2    2
#    ╲╱  x  + y  + z
#
#                                     ⎛          ______________⎞      __________
#                                   2 ⎜         ╱  2    2    2 ⎟     ╱  2    2
#                           -2⋅M + v ⋅⎝-2⋅M + ╲╱  x  + y  + z  ⎠ - ╲╱  x  + y  +
#              0            ────────────────────────────────────────────────────
#                                                      ______________
#                                          ⎛ 2    ⎞   ╱  2    2    2
#                                          ⎝v  - 1⎠⋅╲╱  x  + y  + z
#
#     ⎤
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
#     ⎥
# ____⎥
#   2 ⎥
#  z  ⎥
# ────⎥
#     ⎥
#     ⎥
#     ⎦

# %%
boosted_metric_inv = boosted_metric.inv()
boosted_metric_inv
# Out:
# ⎡                                                                     ⎛
# ⎢                                                                   2 ⎜
# ⎢                                                           -2⋅M + v ⋅⎝-2⋅M +
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢         ⎛                             ⎛          ⎛          ______________⎞
# ⎢         ⎜              2  2           ⎜        2 ⎜         ╱  2    2    2 ⎟
# ⎢⎛ 2    ⎞ ⎜          16⋅M ⋅v            ⎝-2⋅M + v ⋅⎝-2⋅M + ╲╱  x  + y  + z  ⎠
# ⎢⎝v  - 1⎠⋅⎜- ──────────────────────── + ──────────────────────────────────────
# ⎢         ⎜          2
# ⎢         ⎜  ⎛ 2    ⎞  ⎛ 2    2    2⎞
# ⎢         ⎝  ⎝v  - 1⎠ ⋅⎝x  + y  + z ⎠
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢         ⎛                             ⎛          ⎛          ______________⎞
# ⎢         ⎜              2  2           ⎜        2 ⎜         ╱  2    2    2 ⎟
# ⎢⎛ 2    ⎞ ⎜          16⋅M ⋅v            ⎝-2⋅M + v ⋅⎝-2⋅M + ╲╱  x  + y  + z  ⎠
# ⎢⎝v  - 1⎠⋅⎜- ──────────────────────── + ──────────────────────────────────────
# ⎢         ⎜          2
# ⎢         ⎜  ⎛ 2    ⎞  ⎛ 2    2    2⎞
# ⎣         ⎝  ⎝v  - 1⎠ ⋅⎝x  + y  + z ⎠
#
#    ______________⎞      ______________
#   ╱  2    2    2 ⎟     ╱  2    2    2
# ╲╱  x  + y  + z  ⎠ - ╲╱  x  + y  + z
# ──────────────────────────────────────────────────────────────────────────────
#      ______________⎞ ⎛          ⎛         ______________⎞      ______________⎞
#     ╱  2    2    2 ⎟ ⎜        2 ⎜        ╱  2    2    2 ⎟     ╱  2    2    2 ⎟
# - ╲╱  x  + y  + z  ⎠⋅⎝-2⋅M - v ⋅⎝2⋅M + ╲╱  x  + y  + z  ⎠ + ╲╱  x  + y  + z  ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                 2
#         ⎛ 2    ⎞  ⎛ 2    2    2⎞
#         ⎝v  - 1⎠ ⋅⎝x  + y  + z ⎠
#
#
#          0
#
#
#
#
#
#
#
#          0
#
#
#
#
#
#
#
#
#       -4⋅M⋅v
# ──────────────────────────────────────────────────────────────────────────────
#      ______________⎞ ⎛          ⎛         ______________⎞      ______________⎞
#     ╱  2    2    2 ⎟ ⎜        2 ⎜        ╱  2    2    2 ⎟     ╱  2    2    2 ⎟
# - ╲╱  x  + y  + z  ⎠⋅⎝-2⋅M - v ⋅⎝2⋅M + ╲╱  x  + y  + z  ⎠ + ╲╱  x  + y  + z  ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                 2
#         ⎛ 2    ⎞  ⎛ 2    2    2⎞
#         ⎝v  - 1⎠ ⋅⎝x  + y  + z ⎠
#
#
#
#
# ───────────────────            0                      0            ───────────
# ⎞                                                                           ⎛
# ⎟    ______________                                                         ⎜
# ⎟   ╱  2    2    2                                                 ⎛ 2    ⎞ ⎜
# ⎟⋅╲╱  x  + y  + z                                                  ⎝v  - 1⎠⋅⎜-
# ⎟                                                                           ⎜
# ⎟                                                                           ⎜
# ⎠                                                                           ⎝
#
#                                1
#                      ─────────────────────            0
#                             2⋅M
#                      ───────────────── + 1
#                         ______________
#                        ╱  2    2    2
#                      ╲╱  x  + y  + z
#
#                                                       1
#                                0            ─────────────────────
#                                                    2⋅M
#                                             ───────────────── + 1
#                                                ______________
#                                               ╱  2    2    2
#                                             ╲╱  x  + y  + z
#
#
#
#
# ───────────────────            0                      0            ───────────
# ⎞                                                                           ⎛
# ⎟    ______________                                                         ⎜
# ⎟   ╱  2    2    2                                                 ⎛ 2    ⎞ ⎜
# ⎟⋅╲╱  x  + y  + z                                                  ⎝v  - 1⎠⋅⎜-
# ⎟                                                                           ⎜
# ⎟                                                                           ⎜
# ⎠                                                                           ⎝
#
#
#
#                                                                         -4⋅M⋅v
# ──────────────────────────────────────────────────────────────────────────────
#                             ⎛          ⎛          ______________⎞      _______
#              2  2           ⎜        2 ⎜         ╱  2    2    2 ⎟     ╱  2
#          16⋅M ⋅v            ⎝-2⋅M + v ⋅⎝-2⋅M + ╲╱  x  + y  + z  ⎠ - ╲╱  x  + y
#  ──────────────────────── + ──────────────────────────────────────────────────
#          2
#  ⎛ 2    ⎞  ⎛ 2    2    2⎞                                                 ⎛ 2
#  ⎝v  - 1⎠ ⋅⎝x  + y  + z ⎠                                                 ⎝v
#
#
#                                                                            0
#
#
#
#
#
#
#
#                                                                            0
#
#
#
#
#
#
#                                                           ⎛         __________
#                                                         2 ⎜        ╱  2    2
#                                                 -2⋅M - v ⋅⎝2⋅M + ╲╱  x  + y  +
# ──────────────────────────────────────────────────────────────────────────────
#                             ⎛          ⎛          ______________⎞      _______
#              2  2           ⎜        2 ⎜         ╱  2    2    2 ⎟     ╱  2
#          16⋅M ⋅v            ⎝-2⋅M + v ⋅⎝-2⋅M + ╲╱  x  + y  + z  ⎠ - ╲╱  x  + y
#  ──────────────────────── + ──────────────────────────────────────────────────
#          2
#  ⎛ 2    ⎞  ⎛ 2    2    2⎞                                                 ⎛ 2
#  ⎝v  - 1⎠ ⋅⎝x  + y  + z ⎠                                                 ⎝v
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# _______⎞ ⎛          ⎛         ______________⎞      ______________⎞⎞
# 2    2 ⎟ ⎜        2 ⎜        ╱  2    2    2 ⎟     ╱  2    2    2 ⎟⎟    _______
#   + z  ⎠⋅⎝-2⋅M - v ⋅⎝2⋅M + ╲╱  x  + y  + z  ⎠ + ╲╱  x  + y  + z  ⎠⎟   ╱  2
# ──────────────────────────────────────────────────────────────────⎟⋅╲╱  x  + y
#     2                                                             ⎟
#    ⎞  ⎛ 2    2    2⎞                                              ⎟
# - 1⎠ ⋅⎝x  + y  + z ⎠                                              ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ____⎞      ______________
#   2 ⎟     ╱  2    2    2
#  z  ⎠ + ╲╱  x  + y  + z
# ──────────────────────────────────────────────────────────────────────────────
# _______⎞ ⎛          ⎛         ______________⎞      ______________⎞⎞
# 2    2 ⎟ ⎜        2 ⎜        ╱  2    2    2 ⎟     ╱  2    2    2 ⎟⎟    _______
#   + z  ⎠⋅⎝-2⋅M - v ⋅⎝2⋅M + ╲╱  x  + y  + z  ⎠ + ╲╱  x  + y  + z  ⎠⎟   ╱  2
# ──────────────────────────────────────────────────────────────────⎟⋅╲╱  x  + y
#     2                                                             ⎟
#    ⎞  ⎛ 2    2    2⎞                                              ⎟
# - 1⎠ ⋅⎝x  + y  + z ⎠                                              ⎠
#
#        ⎤
#        ⎥
#        ⎥
# ───────⎥
#        ⎥
# _______⎥
# 2    2 ⎥
#   + z  ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
#        ⎥
# ───────⎥
#        ⎥
# _______⎥
# 2    2 ⎥
#   + z  ⎥
#        ⎥
#        ⎥
#        ⎦

# %%
def compute_christoffel(metric):
    if metric.shape != (3, 3):
        raise Exception("Invalid dimensions")

    inv_metric = metric.inv()
    
    out = []
    for i in range(0, 3):
        rows = []
        for j in range(0, 3):
            row = []
            for k in range(0, 3):
                res = 0.0
                for l in range(0, 3):
                    res += inv_metric[i, l] * (
                        Derivative(metric[l, j], coords[k]) +
                        Derivative(metric[l, k], coords[j]) -
                        Derivative(metric[j, k], coords[l]))
                row.append(res / 2)
            rows.append(row)
        out.append(Matrix(rows).applyfunc(simplify))
    return out

def compute_ricci(christoffel):
    if len(christoffel) != 3 or christoffel[0].shape != (3, 3):
        raise Exception("Invalid dimensions")
    rows = []
    for i in range(0, 3):
        row = []
        for j in range(0, 3):
            res = 0.0
            for k in range(0, 3):
                res += Derivative(christoffel[k][i, j], coords[k])
                res -= Derivative(christoffel[k][k, j], coords[i])
                for l in range(0, 3):
                    res += christoffel[k][i, j] * christoffel[l][k, l]
                    res -= christoffel[k][i, l] * christoffel[l][j, k]
            row.append(res)
        rows.append(row)
    return Matrix(rows).applyfunc(simplify) 

def compute_trace(matrix_lo, inv_metric):
    return simplify(matrix_lo[0, 0] * inv_metric[0, 0] +
                    matrix_lo[1, 1] * inv_metric[1, 1] +
                    matrix_lo[2, 2] * inv_metric[2, 2])

# Compute covariant derivative of rank-0 tensor
def compute_diff_scalar(s, christoffel):
    if len(christoffel) != 3:
        raise Exception('Invalid dimensions')

    return Matrix([ diff(s, x) for x in coords ]).applyfunc(simplify)

# Compute covariant derivative of rank-1 covariant tensor
def compute_diff_vec_lo(t, christoffel):
    if len(t) != 3 or len(christoffel) != 3:
        raise Exception('Invalid dimensions')

    rows = []
    for i in range(0, 3):
        row = []
        for j in range(0, 3):
            res = diff(t[i], coords[j])
            for k in range(0, 3):
                res -= christoffel[k][i, j] * t[k]
            row.append(res)
        rows.append(row)
    return Matrix(rows).applyfunc(simplify)

# Compute covariant derivative of rank-2 covariant tensor
def compute_diff_matrix_lo(m, christoffel):
    if m.shape != (3, 3) or len(christoffel) != 3:
        raise Exception('Invalid dimensions')

    out = []
    for i in range(0, 3):
        rows = []
        for j in range(0, 3):
            row = []
            for k in range(0, 3):
                res = diff(m[j, k], coords[i])
                for l in range(0, 3):
                    res -= christoffel[l][i, j] * m[l, k]
                    res -= christoffel[l][i, k] * m[j, l]
                row.append(res)
            rows.append(row)
        out.append(Matrix(rows).applyfunc(simplify))
    return out

# Compute lapse, shift, and K
def compute_factors(metric_full):
    metric_spat = metric_full[1:, 1:]
    inv_metric_full = metric_full.inv()
    
    alpha = (1 / sqrt(-inv_metric_full[0, 0].simplify())).simplify()
    beta_hi = (inv_metric_full[0, 1:] * (alpha ** 2)).applyfunc(simplify)
    beta_lo = metric_full[0, 1:]
    
    inv_metric_spat = inv_metric_full[1:, 1:] + (1 / alpha ** 2) * Matrix([
        [ beta_hi[i] * beta_hi[j] for i in range(0, 3) ]
        for j in range(0, 3)
    ])
    christoffel = compute_christoffel(metric_spat)
    
    diff_beta_lo = compute_diff_vec_lo(beta_lo, christoffel)
    K_lo = Matrix([
        [ diff_beta_lo[i, j] + diff_beta_lo[j, i] for j in range(0, 3) ]
        for i in range(0, 3)
    ])
    K_lo /= (2 * alpha)
    K_lo = K_lo.applyfunc(simplify)
    
    K_hi = inv_metric_spat * K_lo * inv_metric_spat.T
    
    KK = Trace(K_lo * K_hi)
    K = Trace(K_lo * inv_metric_spat).simplify()
    
    ricci = compute_ricci(christoffel)
    R = Trace(ricci * inv_metric_spat).simplify()

    return {
        'alpha': alpha,
        'beta_hi': beta_hi,
        'beta_lo': beta_lo,
        'K_lo': K_lo,
        'K_hi': K_hi,
        'KK': KK.simplify(),
        'K': K,
        
        'christoffel': christoffel,
        
        'metric_spat': metric_spat,
        'inv_metric_spat': inv_metric_spat.applyfunc(simplify),
        
        'ricci': ricci,
        'R': R,
    }

# %%
boosted_factors = compute_factors(boosted_metric)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-afa7399f19e3> in <module>
# ----> 1 boosted_factors = compute_factors(boosted_metric)
#
# <ipython-input-20-a6e49d804562> in compute_factors(metric_full)
#     116     K = Trace(K_lo * inv_metric_spat).simplify()
#     117
# --> 118     ricci = compute_ricci(christoffel)
#     119     R = Trace(ricci * inv_metric_spat).simplify()
#     120
#
# <ipython-input-20-a6e49d804562> in compute_ricci(christoffel)
#      38             row.append(res)
#      39         rows.append(row)
# ---> 40     return Matrix(rows).applyfunc(simplify)
#      41
#      42 def compute_trace(matrix_lo, inv_metric):
#
# /usr/local/lib/python3.7/site-packages/sympy/matrices/common.py in applyfunc(self, f)
#    1723             raise TypeError("`f` must be callable.")
#    1724
# -> 1725         return self._eval_applyfunc(f)
#    1726
#    1727     def as_real_imag(self):
#
# /usr/local/lib/python3.7/site-packages/sympy/matrices/common.py in _eval_applyfunc(self, f)
#    1663
#    1664     def _eval_applyfunc(self, f):
# -> 1665         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1666         return out
#    1667
#
# /usr/local/lib/python3.7/site-packages/sympy/matrices/common.py in <listcomp>(.0)
#    1663
#    1664     def _eval_applyfunc(self, f):
# -> 1665         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1666         return out
#    1667
#
# /usr/local/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     599     expr = Mul(*powsimp(expr).as_content_primitive())
#     600     _e = cancel(expr)
# --> 601     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     602     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#     603
#
# /usr/local/lib/python3.7/site-packages/sympy/core/expr.py in cancel(self, *gens, **args)
#    3565         """See the cancel function in sympy.polys"""
#    3566         from sympy.polys import cancel
# -> 3567         return cancel(self, *gens, **args)
#    3568
#    3569     def invert(self, g, *gens, **args):
#
# /usr/local/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6607         if f.is_Number or isinstance(f, Relational) or not isinstance(f, Expr):
#    6608             return f
# -> 6609         f = factor_terms(f, radical=True)
#    6610         p, q = f.as_numer_denom()
#    6611
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in factor_terms(expr, radical, clear, fraction, sign)
#    1256         return rv
#    1257     expr = sympify(expr)
# -> 1258     return do(expr)
#    1259
#    1260
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in do(expr)
#    1231         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1232         if p.is_Add:
# -> 1233             list_args = [do(a) for a in Add.make_args(p)]
#    1234             # get a common negative (if there) which gcd_terms does not remove
#    1235             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1231         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1232         if p.is_Add:
# -> 1233             list_args = [do(a) for a in Add.make_args(p)]
#    1234             # get a common negative (if there) which gcd_terms does not remove
#    1235             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in do(expr)
#    1252         elif p.args:
#    1253             p = p.func(
# -> 1254                 *[do(a) for a in p.args])
#    1255         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1256         return rv
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1252         elif p.args:
#    1253             p = p.func(
# -> 1254                 *[do(a) for a in p.args])
#    1255         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1256         return rv
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in do(expr)
#    1252         elif p.args:
#    1253             p = p.func(
# -> 1254                 *[do(a) for a in p.args])
#    1255         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1256         return rv
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1252         elif p.args:
#    1253             p = p.func(
# -> 1254                 *[do(a) for a in p.args])
#    1255         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1256         return rv
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in do(expr)
#    1231         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1232         if p.is_Add:
# -> 1233             list_args = [do(a) for a in Add.make_args(p)]
#    1234             # get a common negative (if there) which gcd_terms does not remove
#    1235             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#    1231         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1232         if p.is_Add:
# -> 1233             list_args = [do(a) for a in Add.make_args(p)]
#    1234             # get a common negative (if there) which gcd_terms does not remove
#    1235             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# /usr/local/lib/python3.7/site-packages/sympy/core/exprtools.py in do(expr)
#    1229                 fraction=fraction, sign=sign)
#    1230
# -> 1231         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1232         if p.is_Add:
#    1233             list_args = [do(a) for a in Add.make_args(p)]
#
# /usr/local/lib/python3.7/site-packages/sympy/core/mul.py in as_content_primitive(self, radical, clear)
#    1788         args = []
#    1789         for i, a in enumerate(self.args):
# -> 1790             c, p = a.as_content_primitive(radical=radical, clear=clear)
#    1791             coef *= c
#    1792             if p is not S.One:
#
# /usr/local/lib/python3.7/site-packages/sympy/core/power.py in as_content_primitive(self, radical, clear)
#    1680
#    1681         b, e = self.as_base_exp()
# -> 1682         b = _keep_coeff(*b.as_content_primitive(radical=radical, clear=clear))
#    1683         ce, pe = e.as_content_primitive(radical=radical, clear=clear)
#    1684         if b.is_Rational:
#
# /usr/local/lib/python3.7/site-packages/sympy/core/add.py in as_content_primitive(self, radical, clear)
#    1009         """
#    1010         con, prim = self.func(*[_keep_coeff(*a.as_content_primitive(
# -> 1011             radical=radical, clear=clear)) for a in self.args]).primitive()
#    1012         if not clear and not con.is_Integer and prim.is_Add:
#    1013             con, d = con.as_numer_denom()
#
# /usr/local/lib/python3.7/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /usr/local/lib/python3.7/site-packages/sympy/core/expr.py in __eq__(self, other)
#     138             if not isinstance(a, Expr):
#     139                 continue
# --> 140             if a.is_Number and type(a) != type(b):
#     141                 return False
#     142         return True
#
# KeyboardInterrupt:
